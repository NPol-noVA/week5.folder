# %%
import pandas as pd

rf = pd.read_csv("_data/insurance (4).csv")

# %%
import os

print(os.getcwd())
import os

print(os.listdir())
# Out:
# C:\Users\USER\project_folder
# ['.ipynb_checkpoints', 'Untitled.ipynb', '_data']

# %%
import os

print(os.listdir("_data"))
# Out:
# ['insurance (4).csv']
